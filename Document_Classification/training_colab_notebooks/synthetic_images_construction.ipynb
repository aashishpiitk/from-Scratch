# %% [markdown]
# <a href="https://colab.research.google.com/github/aashishpiitkEigenlytics/lapsrn-document/blob/main/synthetic_images_construction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pathlib import Path
import cv2

# %%
# !pip install trdg
import trdg
# !mkdir custom_data_32x32
# !trdg -c 1000 --output_dir custom_data_32x32 -w 1 -f 32 -wd 32
checking = []
for path in Path("custom_data_32x32/").rglob("*.jpg"):
    checking.append(path)

# !mkdir words_32x32
from tqdm.notebook import tqdm
for img_path in tqdm(checking):
    img = cv2.imread(str(img_path))
    _, name = str(img_path).split("/")
    for i in range(32):
        for j in range(32):
            if (img[i,j]>(150,150, 150)).all():
                img[i,j] = (255, 255, 255)
    
    cv2.imwrite(f"words_64x128/{name}", img)
# Out:
# ...
# 2021-05-24 17:33:17.389357: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 100% 1000/1000 [00:08<00:00, 117.99it/s]
# ...

# %%
! rm -r /content/custom_data_64x128

# %%
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
im = Image.open('/content/custom_data_32x32/Aladfar_538.jpg')
plt.imshow(im)

# %%
! zip -r custom_dataset_64x128_binarized.zip /content/words_64x128
# Out:
#   adding: content/words_64x128/ (stored 0%)
#   adding: content/words_64x128/self-exploiting_83.jpg (deflated 5%)
#   adding: content/words_64x128/piligan_517.jpg (deflated 6%)
#   adding: content/words_64x128/unship_507.jpg (deflated 6%)
#   adding: content/words_64x128/nebuliferous_377.jpg (deflated 6%)
#   adding: content/words_64x128/sanies_629.jpg (deflated 6%)
#   adding: content/words_64x128/androsphinxes_86.jpg (deflated 5%)
#   adding: content/words_64x128/Halakahs_962.jpg (deflated 5%)
#   adding: content/words_64x128/Demi-norman_433.jpg (deflated 6%)
#   adding: content/words_64x128/pseudoliberal_69.jpg (deflated 5%)
#   adding: content/words_64x128/uncognized_762.jpg (deflated 5%)
#   adding: content/words_64x128/integrating_615.jpg (deflated 6%)
#   adding: content/words_64x128/phyllamania_359.jpg (deflated 5%)
#   adding: content/words_64x128/Ensiferi_155.jpg (deflated 5%)
#   adding: content/words_64x128/blunging_562.jpg (deflated 5%)
# ...
